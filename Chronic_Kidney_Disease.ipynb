# %%
import pandas as pd

# %%
dataset=pd.read_csv("kidney_disease.csv")

# %%
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
dataset.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
dataset[["age","bp","sg","al","su","rbc","pc","pcc","ba","bgr","bu","sc","sod","pot","hemo","pcv","wc","rc","htn","dm","cad","appet","pe","ane"]].fillna(0,inplace=True)
# Out:
# <ipython-input-8-8f29f6b2e65a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[["age","bp","sg","al","su","rbc","pc","pcc","ba","bgr","bu","sc","sod","pot","hemo","pcv","wc","rc","htn","dm","cad","appet","pe","ane"]].fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#       id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9      9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11    11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14    14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20    20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
dataset[["age","bp","sg","al","su","rbc","pc","pcc","ba","bgr","bu","sc","sod","pot","hemo","pcv","wc","rc","htn","dm","cad","appet","pe","ane"]].fillna(dataset[["age","bp","sg","al","su","rbc","pc","pcc","ba","bgr","bu","sc","sod","pot","hemo","pcv","wc","rc","htn","dm","cad","appet","pe","ane"]].mean(),inplace=True)
# Out:
# <ipython-input-14-705acfded553>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset[["age","bp","sg","al","su","rbc","pc","pcc","ba","bgr","bu","sc","sod","pot","hemo","pcv","wc","rc","htn","dm","cad","appet","pe","ane"]].fillna(dataset[["age","bp","sg","al","su","rbc","pc","pcc","ba","bgr","bu","sc","sod","pot","hemo","pcv","wc","rc","htn","dm","cad","appet","pe","ane"]].mean(),inplace=True)
# <ipython-input-14-705acfded553>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
dataset
# Out:
#       id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9      9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11    11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14    14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20    20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(dataset)

# %%
dataset[quan]
# Out:
#       id   age    bp     sg   al   su    bgr     bu   sc    sod  pot  hemo
# 3      3  48.0  70.0  1.005  4.0  0.0  117.0   56.0  3.8  111.0  2.5  11.2
# 9      9  53.0  90.0  1.020  2.0  0.0   70.0  107.0  7.2  114.0  3.7   9.5
# 11    11  63.0  70.0  1.010  3.0  0.0  380.0   60.0  2.7  131.0  4.2  10.8
# 14    14  68.0  80.0  1.010  3.0  2.0  157.0   90.0  4.1  130.0  6.4   5.6
# 20    20  61.0  80.0  1.015  2.0  0.0  173.0  148.0  3.9  135.0  5.2   7.7
# ..   ...   ...   ...    ...  ...  ...    ...    ...  ...    ...  ...   ...
# 395  395  55.0  80.0  1.020  0.0  0.0  140.0   49.0  0.5  150.0  4.9  15.7
# 396  396  42.0  70.0  1.025  0.0  0.0   75.0   31.0  1.2  141.0  3.5  16.5
# 397  397  12.0  80.0  1.020  0.0  0.0  100.0   26.0  0.6  137.0  4.4  15.8
# 398  398  17.0  60.0  1.025  0.0  0.0  114.0   50.0  1.0  135.0  4.9  14.2
# 399  399  58.0  80.0  1.025  0.0  0.0  131.0   18.0  1.1  141.0  3.5  15.8
#
# [158 rows x 12 columns]

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])
df = pd.DataFrame(df,columns = quan)

# %%
df
# Out:
#         id   age    bp     sg   al   su    bgr     bu   sc    sod  pot  hemo
# 0      3.0  48.0  70.0  1.005  4.0  0.0  117.0   56.0  3.8  111.0  2.5  11.2
# 1      9.0  53.0  90.0  1.020  2.0  0.0   70.0  107.0  7.2  114.0  3.7   9.5
# 2     11.0  63.0  70.0  1.010  3.0  0.0  380.0   60.0  2.7  131.0  4.2  10.8
# 3     14.0  68.0  80.0  1.010  3.0  2.0  157.0   90.0  4.1  130.0  6.4   5.6
# 4     20.0  61.0  80.0  1.015  2.0  0.0  173.0  148.0  3.9  135.0  5.2   7.7
# ..     ...   ...   ...    ...  ...  ...    ...    ...  ...    ...  ...   ...
# 153  395.0  55.0  80.0  1.020  0.0  0.0  140.0   49.0  0.5  150.0  4.9  15.7
# 154  396.0  42.0  70.0  1.025  0.0  0.0   75.0   31.0  1.2  141.0  3.5  16.5
# 155  397.0  12.0  80.0  1.020  0.0  0.0  100.0   26.0  0.6  137.0  4.4  15.8
# 156  398.0  17.0  60.0  1.025  0.0  0.0  114.0   50.0  1.0  135.0  4.9  14.2
# 157  399.0  58.0  80.0  1.025  0.0  0.0  131.0   18.0  1.1  141.0  3.5  15.8
#
# [158 rows x 12 columns]
